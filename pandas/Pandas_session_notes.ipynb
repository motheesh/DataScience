# %%
import pandas as pd

# %%
data=pd.read_csv("cars.csv", sep=";")
data.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US

# %%
data.dtypes
# Out:
# Car             object
# MPG             object
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
data
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
data.describe()
#count-count of data in that particular column except NAN
#Unique how many unique data available in that particular column
#mean - sum of all column value/count of values in that column
#min - gives the min value of that column
#max - gives max value 0f that column
#std - std for that particular column
# Out:
#                    Car   MPG Cylinders Displacement Horsepower Weight  \
# count              407   407       407          407        407    407
# unique             309   131         6           84         95    357
# top     Toyota Corolla  13.0         4        97.00      150.0  1985.
# freq                 9    20       207           22         22      4
#
#        Acceleration Model Origin
# count           407   407    407
# unique           98    14      4
# top            14.5    73     US
# freq             23    40    254

# %%
data_from_Html=pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
len(data_from_Html)
# Out:
# 6

# %%
data_from_Html[0].to_csv("basketball.csv",index=None)

# %%
data_link=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

data_link.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import requests
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js=res.json()

keys=[j for j in js[0]]
print(keys)

for i in js:
    print(i["url"])
# Out:
# ['url', 'repository_url', 'labels_url', 'comments_url', 'events_url', 'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels', 'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments', 'created_at', 'updated_at', 'closed_at', 'author_association', 'active_lock_reason', 'pull_request', 'body', 'performed_via_github_app']
# https://api.github.com/repos/pandas-dev/pandas/issues/41825
# https://api.github.com/repos/pandas-dev/pandas/issues/41824
# https://api.github.com/repos/pandas-dev/pandas/issues/41823
# https://api.github.com/repos/pandas-dev/pandas/issues/41822
# https://api.github.com/repos/pandas-dev/pandas/issues/41821
# https://api.github.com/repos/pandas-dev/pandas/issues/41819
# https://api.github.com/repos/pandas-dev/pandas/issues/41818
# https://api.github.com/repos/pandas-dev/pandas/issues/41817
# https://api.github.com/repos/pandas-dev/pandas/issues/41815
# https://api.github.com/repos/pandas-dev/pandas/issues/41813
# ...

# %%
import requests
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
js=res.json()



#format 1
pd.DataFrame([ii["user"] for ii in js])


#format 2
dt=pd.DataFrame(js,columns=["user"])
js1=dt["user"].to_json()
pd.read_json(js1).T.head()
# Out:
#              login        id               node_id  \
# 0  michaelshekasta  41590425  MDQ6VXNlcjQxNTkwNDI1
# 1    kerrickstaley    184773  MDQ6VXNlcjE4NDc3Mw==
# 2     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3              rok     54589      MDQ6VXNlcjU0NTg5
# 4     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/415904...
# 1  https://avatars.githubusercontent.com/u/184773...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/54589?v=4
# 4  https://avatars.githubusercontent.com/u/807896...
#
#                                             url  \
# 0  https://api.github.com/users/michaelshekasta
# 1    https://api.github.com/users/kerrickstaley
# 2     https://api.github.com/users/jbrockmendel
# 3              https://api.github.com/users/rok
# 4     https://api.github.com/users/jbrockmendel
#
# ...

# %% [markdown]
# ### serialization
#      - convert object to bytecode
#
# ### de-serialization
#      - convert bytecode to object
#
#
# ### to_pickle
#     -store data in non readable format
#     - only can be accessibly by programming language
#
# #### hdfstore
#     - create a instance and allows us to store data in the form of object

# %%
data_link=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df=data_link
data_link.dtypes
data_link.describe()
data_link.dtypes=="object"

data_link.dtypes[data_link.dtypes=="object"]
data_link.dtypes[data_link.dtypes=="object"].index

data_link[data_link.dtypes[data_link.dtypes=="object"].index]

data_link.columns
pd.Categorical(data_link["Sex"])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
Cabin_non_null_data=data_link["Cabin"][data_link["Cabin"].isnull()==False]
len(Cabin_non_null_data.index)
# Out:
# 204

# %%
data_link["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df["Fare"]==max(df["Fare"])]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["new_col"]=df["PassengerId"]+df["Age"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
#
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
# https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv

# %%
data_df=pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
data_df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
import pandas as pd

data_df=pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")


#create new column for price without dollar symbol 
data_df["price"]=data_df["item_price"].replace('[\$,]', '', regex=True).astype(float)
#data_df["price"]=data_df["price"].astype(str).astype(int)
print(data_df["price"].dtypes)

#find sum of price
print("sum of Price: ",sum(data_df["price"]))

#find max price
print("max price : ",max(data_df["price"]))
#get the min price
print("min Price: ",min(data_df["price"]))


#get item_name with heighest price
print("max price : ",data_df[["item_name","price"]][data_df["price"]==max(data_df["price"])])


#get item_name with lowest pric
min_price=data_df[["item_name","price"]][data_df["price"]==min(data_df["price"])]
print("item with min price : ",min_price.iloc[0].price, " ",min_price.iloc[0].item_name)


#how many unique items present
print("how many unique items present",len(data_df["item_name"].unique()))

#get the total product worth of all items

print("Total Product Worth is :",(sum(data_df["quantity"]*data_df["price"])))

#how many items we have below given range of price 
price_range=30
print(f"items we have below {price_range} range of price is :",len(data_df["item_name"][data_df["price"]<price_range].unique()))


#how many items we have above the given range of price 
price_range=30
print(f"items we have above {price_range} range of price is :",len(data_df["item_name"][data_df["price"]>price_range].unique()))

#get the average price of all items
print("average price of all items",data_df.describe()["price"]["mean"])

#data_df.describe()
# Out:
# float64
# sum of Price:  34500.16000000046
# max price :  44.25
# min Price:  1.09
# max price :                           item_name  price
# 3598  Chips and Fresh Tomato Salsa  44.25
# item with min price :  1.09   Canned Soda
# how many unique items present 50
# Total Product Worth is : 39237.020000000055
# items we have below 30 range of price is : 50
# items we have above 30 range of price is : 5
# average price of all items 7.464335785374397
#           order_id     quantity        price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %%
#get items with price less than given number
# Out:
# hello
